# %% [markdown]
# <a href="https://colab.research.google.com/github/stella-melgaco/stella-melgaco/blob/main/stella_melgaco_atividade_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stella Melgaço
# ---

# %% [markdown]
# ### **Formação**
#   - Oceanógrafa - UERJ
#   - Mestre em Engenharia Ambiental - UERJ
#   - Doutoranda em Dinâmica dos Oceanos e da Terra - UFF

# %% [markdown]
# ### **Projeto de doutorado**
# Título: *Contaminação histórica e variação espacial de micropoluentes orgânicos e metais em sedimentos de manguezais do estado do Rio de Janeiro*
# 1. Coleta de testemunho em manguezais  <img align="right" src= "https://ecoinforme.com.br/wp-content/uploads/2018/02/manguezais.jpg" alt="drawing" width="180" />
#     * Foz do Rio Estrela
#     * Foz do Rio Paraíba do Sul
#     * a definir
#
# 1. Datação - <sup>210</sup>Pb
# 1. Otimização de metodologia de extração de micropoluentes orgânicos em sedimentos
#
# 1. Determinação das concentrações de micropoluentes orgânicos e metais nas camadas de sedimento

# %% [markdown]
# ### **Interesses pessoais**
#   - Filmes <img src= "https://img.freepik.com/vetores-gratis/desenho-de-placa-de-badalo-de-filme-em-branco-simbolo-de-producao-do-filme_53734-45.jpg?w=740" alt="drawing" width="30" />
#     - *Segredo dos seus olhos*
#
#       <img src="data:image/jpeg;base64,..." alt="drawing" width="100" />
#     - *Memórias de um assassino*
#    <img src="data:image/jpeg;base64,..." alt="drawing" width="150" />
#
#     - *Antes do pôr do sol*
# <img src= "data:image/jpeg;base64,..." alt="drawing" width="100" />

# %% [markdown]
# ### Música <img src= "https://thumbs.dreamstime.com/b/s%C3%ADmbolo-simples-da-nota-musical-conceito-clave-de-sol-notas-m%C3%BAsica-com-etiqueta-sinal-logotipo-129293222.jpg" alt="drawing" width="30"/>
# 1. Renato Russo
# - Gonzaguinha
# - Maria Bethânia
# - Caetano Veloso
# - Marisa Monte

# %% [markdown]
# <p align="center">
# <img src="https://media.giphy.com/media/vFKqnCdLPNOKc/giphy.gif" width="200" align="center" />
#
#
# -----
